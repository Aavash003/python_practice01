# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup("https://www.worldometers.info/coronavirus/","html.parser")
soup = requests.get(url)
soup
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12276\933022301.py:3: MarkupResemblesLocatorWarning:
#
# The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
# <Response [200]>

# %%
#soup.text

# %%
soup = BeautifulSoup(soup.text,"lxml") #converting to lxml
table_code = soup.table
table_code
# Out:
# <table class="table table-bordered table-hover main_table_countries" id="main_table_countries_today" style="width:100%;margin-top: 0px !important;display:none;">
# <thead>
# <tr>
# <th width="1%">#</th>
# <th width="100">Country,<br/>Other</th>
# <th width="20">Total<br/>Cases</th>
# <th width="30">New<br/>Cases</th>
# <th width="30">Total<br/>Deaths</th>
# <th width="30">New<br/>Deaths</th>
# <th width="30">Total<br/>Recovered</th>
# <th width="30">New<br/>Recovered</th>
# <th width="30">Active<br/>Cases</th>
# <th width="30">Serious,<br/>Critical</th>
# <th width="30">Tot Cases/<br/>1M pop</th>
# <th width="30">Deaths/<br/>1M pop</th>
# <th width="30">Total<br/>Tests</th>
# <th width="30">Tests/<br/>
# <nobr>1M pop</nobr>
# </th>
# <th width="30">Population</th>
# <th style="display:none" width="30">Continent</th>
# <th width="30">1 Case<br/>every X ppl</th><th width="30">1 Death<br/>every X ppl</th><th width="30">1 Test<br/>every X ppl</th>
# <th width="30">New Cases/1M pop</th>
# ...

# %%
tags = table_code.find_all("tr")
tags
#print(type(tags))
#tags[-1].text
# Out:
# [<tr>
#  <th width="1%">#</th>
#  <th width="100">Country,<br/>Other</th>
#  <th width="20">Total<br/>Cases</th>
#  <th width="30">New<br/>Cases</th>
#  <th width="30">Total<br/>Deaths</th>
#  <th width="30">New<br/>Deaths</th>
#  <th width="30">Total<br/>Recovered</th>
#  <th width="30">New<br/>Recovered</th>
#  <th width="30">Active<br/>Cases</th>
#  <th width="30">Serious,<br/>Critical</th>
#  <th width="30">Tot Cases/<br/>1M pop</th>
#  <th width="30">Deaths/<br/>1M pop</th>
#  <th width="30">Total<br/>Tests</th>
#  <th width="30">Tests/<br/>
#  <nobr>1M pop</nobr>
#  </th>
#  <th width="30">Population</th>
#  <th style="display:none" width="30">Continent</th>
#  <th width="30">1 Case<br/>every X ppl</th><th width="30">1 Death<br/>every X ppl</th><th width="30">1 Test<br/>every X ppl</th>
#  <th width="30">New Cases/1M pop</th>
#  <th width="30">New Deaths/1M pop</th>
#  <th width="30">Active Cases/1M pop</th>
#  </tr>,
# ...

# %%
data = []
for i in tags:
    y = i.text.split("\n")[1:]
    if y[0] != "":
        data.append(y)

data
# Out:
# [['#',
#   'Country,Other',
#   'TotalCases',
#   'NewCases',
#   'TotalDeaths',
#   'NewDeaths',
#   'TotalRecovered',
#   'NewRecovered',
#   'ActiveCases',
#   'Serious,Critical',
#   'Tot\xa0Cases/1M pop',
#   'Deaths/1M pop',
#   'TotalTests',
#   'Tests/',
#   '1M pop',
#   '',
#   'Population',
#   'Continent',
#   '1 Caseevery X ppl1 Deathevery X ppl1 Testevery X ppl',
#   'New Cases/1M pop',
#   'New Deaths/1M pop',
#   'Active Cases/1M pop',
#   ''],
#  ['1',
#   'USA',
#   '111,558,488',
#   '',
#   '1,216,367                                ',
#   '',
#   '109,308,801',
#   '',
#   '1,033,320',
#   '1,550',
#   '333,204',
#   '3,633',
#   '1,186,765,074',
#   '3,544,643',
#   '334,805,269 ',
#   'North America',
#   '',
#   '32750',
#   '',
#   '',
#   '3,086',
#   ''],
#  ['2',
#   'India',
#   '45,030,332',
#   '+120',
#   '533,496                                ',
#   '+1',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   '32,013',
#   '379',
#   '935,879,495',
# ...

# %%
type(data[0])
# Out:
# list

# %%
data[0]
# Out:
# ['#',
#  'Country,Other',
#  'TotalCases',
#  'NewCases',
#  'TotalDeaths',
#  'NewDeaths',
#  'TotalRecovered',
#  'NewRecovered',
#  'ActiveCases',
#  'Serious,Critical',
#  'Tot\xa0Cases/1M pop',
#  'Deaths/1M pop',
#  'TotalTests',
#  'Tests/',
#  '1M pop',
#  '',
#  'Population',
#  'Continent',
#  '1 Caseevery X ppl1 Deathevery X ppl1 Testevery X ppl',
#  'New Cases/1M pop',
#  'New Deaths/1M pop',
#  'Active Cases/1M pop',
#  '']

# %%
import csv
import pandas as pd

file = open("covid.csv","w")
x = csv.writer(file)
x.writerows(data)
file.close()

# %%
df = pd.read_csv("covid.csv",encoding = "latin1")
df.head(10)
# Out:
#     # Country,Other   TotalCases  NewCases  \
# 0   1           USA  111,558,488       NaN
# 1   2         India   45,030,212       NaN
# 2   3        France   40,138,560       NaN
# 3   4       Germany   38,822,474       NaN
# 4   5        Brazil   38,452,504       NaN
# 5   6      S. Korea   34,571,873       NaN
# 6   7         Japan   33,803,572       NaN
# 7   8         Italy   26,719,511       NaN
# 8   9            UK   24,902,971       NaN
# 9  10        Russia   23,983,769       NaN
#
#                                  TotalDeaths  NewDeaths TotalRecovered  \
# 0  1,216,367                                        NaN    109,308,801
# 1    533,495                                        NaN            NaN
# 2    167,642                                        NaN     39,970,918
# 3    182,649                                        NaN     38,240,600
# 4    709,963                                        NaN     36,249,161
# ...

# %%
df.shape
# Out:
# (231, 23)

# %%
df.columns
# Out:
# Index(['#', 'Country,Other', 'TotalCases', 'NewCases', 'TotalDeaths',
#        'NewDeaths', 'TotalRecovered', 'NewRecovered', 'ActiveCases',
#        'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop', 'TotalTests',
#        'Tests/', '1M pop', 'Unnamed: 15', 'Population', 'Continent',
#        '1 Caseevery X ppl1 Deathevery X ppl1 Testevery X ppl',
#        'New Cases/1M pop', 'New Deaths/1M pop', 'Active Cases/1M pop',
#        'Unnamed: 22'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# #                                                         0
# Country,Other                                             0
# TotalCases                                                0
# NewCases                                                227
# TotalDeaths                                               0
# NewDeaths                                               231
# TotalRecovered                                           48
# NewRecovered                                            223
# ActiveCases                                              47
# Serious,Critical                                        179
# Tot Cases/1M pop                                          2
# Deaths/1M pop                                             7
# TotalTests                                               18
# Tests/                                                   18
# 1M pop                                                    0
# Unnamed: 15                                               2
# ...

# %%
df.describe()
# Out:
#                 #   NewCases  NewDeaths  NewRecovered  Population  \
# count  231.000000    4.00000        0.0      8.000000         0.0
# mean   116.000000  115.25000        NaN    213.250000         NaN
# std     66.828138  217.19327        NaN    212.206604         NaN
# min      1.000000    2.00000        NaN     16.000000         NaN
# 25%     58.500000    6.50000        NaN     50.250000         NaN
# 50%    116.000000    9.00000        NaN    181.000000         NaN
# 75%    173.500000  117.75000        NaN    279.000000         NaN
# max    231.000000  441.00000        NaN    665.000000         NaN
#
#        1 Caseevery X ppl1 Deathevery X ppl1 Testevery X ppl  New Cases/1M pop  \
# count                                            4.00000                  0.0
# mean                                             5.50000                  NaN
# std                                              7.72442                  NaN
# ...

# %%
#plotting top 10 countries data
x = df["Country,Other"][:10]
y = df["TotalCases"][:10]
# Out:
# 0    111,558,488
# 1     45,030,212
# 2     40,138,560
# 3     38,822,474
# 4     38,452,504
# 5     34,571,873
# 6     33,803,572
# 7     26,719,511
# 8     24,902,971
# 9     23,983,769
# Name: TotalCases, dtype: object

# %%
y = [int(i.replace(",","")) for i in y]
df["TotalCases"][:10] = y
df
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12276\2813676585.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        #   Country,Other TotalCases  NewCases  \
# 0      1             USA  111558488       NaN
# 1      2           India   45030212       NaN
# 2      3          France   40138560       NaN
# 3      4         Germany   38822474       NaN
# 4      5          Brazil   38452504       NaN
# ..   ...             ...        ...       ...
# 226  227         Tokelau         80       NaN
# 227  228    Vatican City         29       NaN
# 228  229  Western Sahara         10       NaN
# 229  230      MS Zaandam          9       NaN
# 230  231           China    503,302       NaN
#
#                                    TotalDeaths  NewDeaths TotalRecovered  \
# ...

# %%
# !pip install plotly == 5.19.0

# %% [markdown]
# # TotalCases vs Country,Other

# %%
import plotly.express as px
fig = px.bar(df[:10], x='Country,Other', y='TotalCases')
fig.show()
# Out:
# <div>                            <div id="00bf6dcd-53fa-43dc-81ef-9fe4d966dd5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00bf6dcd-53fa-43dc-81ef-9fe4d966dd5d")) {                    Plotly.newPlot(                        "00bf6dcd-53fa-43dc-81ef-9fe4d966dd5d",                        [{"alignmentgroup":"True","hovertemplate":"Country,Other=%{x}<br>TotalCases=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"xaxis":"x","y":[111558488,45030212,40138560,38822474,38452504,34571873,33803572,26719511,24902971,23983769],"yaxis":"y","type"
# ...

# %%
y1 = df["TotalDeaths"][:10]
y1 = [int(i.replace(",","")) for i in y1]
df["TotalDeaths"][:10] = y1
df
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12276\2412333408.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        #   Country,Other TotalCases  NewCases  \
# 0      1             USA  111558488       NaN
# 1      2           India   45030212       NaN
# 2      3          France   40138560       NaN
# 3      4         Germany   38822474       NaN
# 4      5          Brazil   38452504       NaN
# ..   ...             ...        ...       ...
# 226  227         Tokelau         80       NaN
# 227  228    Vatican City         29       NaN
# 228  229  Western Sahara         10       NaN
# 229  230      MS Zaandam          9       NaN
# 230  231           China    503,302       NaN
#
#                                TotalDeaths  NewDeaths TotalRecovered  \
# ...

# %% [markdown]
# # TotalCases vs TotalDeaths

# %% [markdown]
# # Grouped Bar Chart

# %%
import plotly.graph_objects as go
#animals=['giraffes', 'orangutans', 'monkeys']

fig = go.Figure(data=[
    go.Bar(name='TotalCases', x=df["Country,Other"][:10], y=df["TotalCases"][:10]),
    go.Bar(name='TotalDeaths', x=df["Country,Other"][:10], y=df["TotalDeaths"][:10])
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()
# Out:
# <div>                            <div id="bfd62532-16e7-49d3-8645-50698ad84d79" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfd62532-16e7-49d3-8645-50698ad84d79")) {                    Plotly.newPlot(                        "bfd62532-16e7-49d3-8645-50698ad84d79",                        [{"name":"TotalCases","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"y":[111558488,45030212,40138560,38822474,38452504,34571873,33803572,26719511,24902971,23983769],"type":"bar"},{"name":"TotalDeaths","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"y":[1216367,533495,167642,182649,709963,35934,74694,196348,232112,402329],"type":"bar"}],                        {"template":{"data":{
# ...

# %% [markdown]
# # TotalCases vs TotalRecovered

# %%
y2 = df["TotalRecovered"][:10]
y2_list = []
for values in y2:
    if type(values) == type(str()):
        t = values.replace(',',"")
        y2_list.append(float(t))
    else:
        y2_list.append(values)

# %%
df["TotalRecovered"][:10] = y2_list
mean = df["TotalRecovered"][:10].mean()

df["TotalRecovered"][:10].fillna(mean,inplace=True)
df.head(10)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12276\3721126152.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     # Country,Other TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0   1           USA  111558488       NaN     1216367        NaN
# 1   2         India   45030212       NaN      533495        NaN
# 2   3        France   40138560       NaN      167642        NaN
# 3   4       Germany   38822474       NaN      182649        NaN
# 4   5        Brazil   38452504       NaN      709963        NaN
# 5   6      S. Korea   34571873       NaN       35934        NaN
# 6   7         Japan   33803572       NaN       74694        NaN
# 7   8         Italy   26719511       NaN      196348        NaN
# 8   9            UK   24902971       NaN      232112        NaN
# ...

# %%
mean
# Out:
# 41590253.875

# %% [markdown]
# # Stacked Bar Chart

# %%
import plotly.graph_objects as go
#animals=['giraffes', 'orangutans', 'monkeys']

fig = go.Figure(data=[
    go.Bar(name='TotalCases', x=df["Country,Other"][:10], y=df["TotalCases"][:10]),
    go.Bar(name='TotalDeaths', x=df["Country,Other"][:10], y=df["TotalRecovered"][:10])
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>                            <div id="e965827f-fbd2-4a42-91dd-e06397c07080" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e965827f-fbd2-4a42-91dd-e06397c07080")) {                    Plotly.newPlot(                        "e965827f-fbd2-4a42-91dd-e06397c07080",                        [{"name":"TotalCases","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"y":[111558488,45030212,40138560,38822474,38452504,34571873,33803572,26719511,24902971,23983769],"type":"bar"},{"name":"TotalDeaths","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"y":[109308801.0,41590253.875,39970918.0,38240600.0,36249161.0,34535939.0,41590253.875,26351971.0,24666932.0,23397709.0],"type":"bar"}]
# ...

# %% [markdown]
# # TotalCases vs ActiveCases

# %%
y3 = df["ActiveCases"][:10]
y3_list = []
for values in y3:
    if type(values) == type(str()):
        t = values.replace(',',"")
        y3_list.append(float(t))
    else:
        y3_list.append(values)

# %%
df["ActiveCases"][:10] = y3_list
mean = df["ActiveCases"][:10].mean()

df["ActiveCases"][:10].fillna(mean,inplace=True)
df.head(10)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12276\1390562264.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     # Country,Other TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0   1           USA  111558488       NaN     1216367        NaN
# 1   2         India   45030212       NaN      533495        NaN
# 2   3        France   40138560       NaN      167642        NaN
# 3   4       Germany   38822474       NaN      182649        NaN
# 4   5        Brazil   38452504       NaN      709963        NaN
# 5   6      S. Korea   34571873       NaN       35934        NaN
# 6   7         Japan   33803572       NaN       74694        NaN
# 7   8         Italy   26719511       NaN      196348        NaN
# 8   9            UK   24902971       NaN      232112        NaN
# ...

# %%
mean
# Out:
# 410596.875

# %% [markdown]
# # Donut Chart

# %%
import plotly.graph_objects as go

labels = df["Country,Other"][:10]
values = df["ActiveCases"]

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.5)])
fig.show()
# Out:
# <div>                            <div id="6d03d464-148d-4a4f-bdc2-674c395308a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d03d464-148d-4a4f-bdc2-674c395308a2")) {                    Plotly.newPlot(                        "6d03d464-148d-4a4f-bdc2-674c395308a2",                        [{"hole":0.5,"labels":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia"],"values":[1033320.0,410596.875,0.0,399225.0,1493380.0,0.0,410596.875,171192.0,3927.0,183731.0,null,"30,634","9,958","941,018","0","0","848","467,986",null,"19,839",null,"44,821",null,"3,811","244","0","52,814","8,011","13,342","2,603","30,592","0","40,035","887","0","880","6,138","61,362","2,068","0","1,530","4,056","769","517","4,338","673","28,792",null,"0"
# ...

# %%
df
# Out:
#        #   Country,Other TotalCases  NewCases  \
# 0      1             USA  111558488       NaN
# 1      2           India   45030212       NaN
# 2      3          France   40138560       NaN
# 3      4         Germany   38822474       NaN
# 4      5          Brazil   38452504       NaN
# ..   ...             ...        ...       ...
# 226  227         Tokelau         80       NaN
# 227  228    Vatican City         29       NaN
# 228  229  Western Sahara         10       NaN
# 229  230      MS Zaandam          9       NaN
# 230  231           China    503,302       NaN
#
#                                TotalDeaths  NewDeaths TotalRecovered  \
# 0                                  1216367        NaN    109308801.0
# 1                                   533495        NaN   41590253.875
# 2                                   167642        NaN     39970918.0
# 3                                   182649        NaN     38240600.0
# ...
